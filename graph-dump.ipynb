# %%
# Install and load packages
library(ggplot2)
install.packages("gridExtra", repos="http://cran.rstudio.com/")
library(gridExtra)
library(scales)
# Out:
# The downloaded source packages are in
# 	‘/private/var/folders/v9/6_3q92b512q408c7y9_mw55h0000gn/T/RtmpowxxzG/downloaded_packages’
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
## EEL POND LOG.OUT TO ANNOTATED GRAPH
# Highlighting is specific to each run, so user will need to 
# change highlighting and text positions for each run

# Load data, name column headers
# Fill in path to file with desired path here

log.data <- read.table("~/old-streaming/eel-pond-streaming-2016-output/output/nonstreaming/2016-02-29/log.out")
colnames(log.data) <- c("TIME", "CPU","RAM","DISK","5","6","7","8")

# Divide RAM column by 1e6 to get from bytes to MB, DISK by 1e2

log.data$RAM <- log.data$RAM/1e6
log.data$DISK <- log.data$DISK/1e2

# Plot each graph (cpu, ram, disk) separately, 
# then use grid.arrange to stack
# ns = nonstreaming, subset

cpuplotns <- ggplot(data=log.data, aes_string(x="TIME", y="CPU")) + 
  geom_line(color = "blue") + xlab("") + ylab("CPU load (100%)") +
  ggtitle("SUBSET - Nonstreaming") + theme(axis.text.x = 
  element_blank(), axis.text.y = element_text(size = 16, color = "black", 
  face = "bold"), plot.title = element_text(face = "bold", size = 13.5))

ramplotns <- ggplot(data=log.data, aes_string(x="TIME", y="RAM")) + 
  geom_line(color = "red") + xlab("") + ylab("RAM (GB)") +
  theme(axis.text.x = element_blank(), axis.text.y = element_text(
    size = 13.5, color = "black", face = "bold"))

diskplotns <- ggplot(data=log.data, aes_string(x="TIME", y="DISK")) + 
  geom_line(color = "green") + xlab("Time (seconds)") + ylab("Disk (kTPS)") +
  theme(axis.text.x = element_text(size = 20, color = "black", 
  face = "bold"), axis.text.y = element_text(size = 13.5, 
  color = "black", face = "bold"))

grid.arrange(cpuplotns,ramplotns,diskplotns)
# Out:
# plot without title

# %%
## EEL POND LOG.OUT TO ANNOTATED GRAPH
# Highlighting is specific to each run, so user will need to 
# change highlighting and text positions for each run

# Load data, name column headers
# Fill in path to file with desired path here

log.data <- read.table("~/git/ep-streaming/output/streaming/2016-05-17-firstfixedsub/log.out")
colnames(log.data) <- c("TIME", "CPU","RAM","DISK","5","6","7","8")

# Divide RAM column by 1e6 to get from bytes to MB, DISK by 1e2

log.data$RAM <- log.data$RAM/1e6
log.data$DISK <- log.data$DISK/1e2

# Plot each graph (cpu, ram, disk) separately, 
# then use grid.arrange to stack
# ss = streaming subset

cpuplotss <- ggplot(data=log.data, aes_string(x="TIME", y="CPU")) + 
  geom_line(color = "blue") + xlab("") + ylab("CPU load (100%)") +
  ggtitle("SUBSET - Streaming") + theme(axis.text.x = 
  element_blank(), axis.text.y = element_text(size = 16, color = "black", 
  face = "bold"), plot.title = element_text(face = "bold", size = 13.5))

cpuplotssa <- cpuplotss + annotate("text", x = 60, y = 90, label = "QC") +
  annotate("rect", xmin = 10, xmax = 20, ymin = 0, ymax = 100,
            fill = "magenta", alpha = .2) +
  annotate("text", x = 300, y = 60, label = "diginorm") +
  annotate("rect", xmin = 170, xmax = 450, ymin = 0, ymax = 100,
           fill = "purple", alpha = .2) +
  annotate("text", x =  580, y = 30, label = "assembly") +
  annotate("rect", xmin = 450, xmax = 640, ymin = 0, ymax = 100,
           fill = "orange", alpha = .2) 

ramplotss <- ggplot(data=log.data, aes_string(x="TIME", y="RAM")) + 
  geom_line(color = "red") + xlab("") + ylab("RAM (GB)") +
  theme(axis.text.x = element_blank(), axis.text.y = element_text(
    size = 13.5, color = "black", face = "bold"))

diskplotss <- ggplot(data=log.data, aes_string(x="TIME", y="DISK")) + 
  geom_line(color = "green") + xlab("Time (seconds)") + ylab("Disk (kTPS)") +
  theme(axis.text.x = element_text(size = 20, color = "black", 
  face = "bold"), axis.text.y = element_text(size = 13.5, 
  color = "black", face = "bold"))

grid.arrange(cpuplotssa,ramplotss,diskplotss)
# Out:
# plot without title

# %%
## EEL POND LOG.OUT TO ANNOTATED GRAPH
# Highlighting is specific to each run, so user will need to 
# change highlighting and text positions for each run

# Load data, name column headers
# Fill in path to file with desired path here

log.data <- read.table("~/git/ep-streaming/output/semistreaming/2016-05-17-sub-final/log.out")
colnames(log.data) <- c("TIME", "CPU","RAM","DISK","5","6","7","8")

# Divide RAM column by 1e6 to get from bytes to MB, DISK by 1e2

log.data$RAM <- log.data$RAM/1e6
log.data$DISK <- log.data$DISK/1e2

# Plot each graph (cpu, ram, disk) separately, 
# then use grid.arrange to stack
# ss = streaming subset

cpuplotsss <- ggplot(data=log.data, aes_string(x="TIME", y="CPU")) + 
  geom_line(color = "blue") + xlab("") + ylab("CPU load (100%)") +
  ggtitle("SUBSET - Semistreaming") + theme(axis.text.x = 
  element_blank(), axis.text.y = element_text(size = 16, color = "black", 
  face = "bold"), plot.title = element_text(face = "bold", size = 13.5))

ramplotsss <- ggplot(data=log.data, aes_string(x="TIME", y="RAM")) + 
  geom_line(color = "red") + xlab("") + ylab("RAM (GB)") +
  theme(axis.text.x = element_blank(), axis.text.y = element_text(
    size = 13.5, color = "black", face = "bold"))

diskplotsss <- ggplot(data=log.data, aes_string(x="TIME", y="DISK")) + 
  geom_line(color = "green") + xlab("Time (seconds)") + ylab("Disk (kTPS)") +
  theme(axis.text.x = element_text(size = 20, color = "black", 
  face = "bold"), axis.text.y = element_text(size = 13.5, 
  color = "black", face = "bold"))

grid.arrange(cpuplotsss,ramplotsss,diskplotsss)
# Out:
# plot without title

# %%
# View both graphs next to each other
grid.arrange(cpuplotns,ramplotns,diskplotns)
grid.arrange(cpuplotss,ramplotss,diskplotss)
grid.arrange(cpuplotsss,ramplotsss,diskplotsss)
# Out:
# plot without title
# plot without title
# plot without title

# %%
# View both graphs next to each other
grid.arrange(cpuplotns,cpuplotss,cpuplotsss)
# Out:
# plot without title

# %%
# View both graphs next to each other
# Nonstreaming on top, streaming on bottom
# t = title
ramplotnst <- ramplotns + ggtitle("SUBSET - Nonstreaming")
ramplotsst <- ramplotss + ggtitle("Streaming Algorithm on Data Subset")
ramplotssst <- ramplotsss + ggtitle("Semistreaming Algorithm on Data Subset")
grid.arrange(ramplotnst,ramplotsst, ramplotssst)
# Out:
# plot without title

# %%
# View both graphs next to each other
# Nonstreaming on top, streaming on bottom
# t = title
diskplotnst <- diskplotns + ggtitle("SUBSET - Nonstreaming")
diskplotsst <- diskplotss + ggtitle("SUBSET - Streaming")
diskplotssst <- diskplotsss + ggtitle("SUBSET - Semistreaming")
grid.arrange(diskplotnst,diskplotsst,diskplotssst)
# Out:
# plot without title

# %%
## EEL POND LOG.OUT TO ANNOTATED GRAPH
# Highlighting is specific to each run, so user will need to 
# change highlighting and text positions for each run

# Load data, name column headers
# Fill in path to file with desired path here

log.data <- read.table("~/git/ep-streaming/output/nonstreaming/2016-05-02/log.out")
colnames(log.data) <- c("TIME", "CPU","RAM","DISK","5","6","7","8")

# Divide RAM column by 1e6 to get from bytes to MB, DISK by 1e2

log.data$RAM <- log.data$RAM/1e6
log.data$DISK <- log.data$DISK/1e2

# Plot each graph (cpu, ram, disk) separately, 
# then use grid.arrange to stack
# nf = nonstreaming, full

cpuplotnf <- ggplot(data=log.data, aes_string(x="TIME", y="CPU")) + 
  geom_line(color = "blue") + xlab("") + ylab("CPU load (100%)") +
  ggtitle("FULL DATA - Nonstreaming") + theme(axis.text.x = 
  element_blank(), axis.text.y = element_text(size = 16, color = "black", 
  face = "bold"), plot.title = element_text(face = "bold", size = 13.5))

cpuplotnfa <- cpuplotnf + annotate("text", x = 4000, y = 90, label = "trimming") +
  annotate("rect", xmin = 48, xmax = 9605, ymin = 0, ymax = 100,
            fill = "blue", alpha = .2) +
  annotate("text", x = 15000, y = 60, label = "diginorm") +
  annotate("rect", xmin = 9605, xmax = 19834, ymin = 0, ymax = 100,
           fill = "yellow", alpha = .2) +
  annotate("text", x =  90000, y = 70, label = "assembly") +
  annotate("rect", xmin = 19834, xmax = 138746, ymin = 0, ymax = 100,
           fill = "magenta", alpha = .2) 

ramplotnf <- ggplot(data=log.data, aes_string(x="TIME", y="RAM")) + 
  geom_line(color = "red") + xlab("") + ylab("RAM (GB)") +
  theme(axis.text.x = element_blank(), axis.text.y = element_text(
    size = 13.5, color = "black", face = "bold"))

ramplotnfa <- ramplotnf + 
  annotate("rect", xmin = 48, xmax = 9605, ymin = 0, ymax = 70,
            fill = "blue", alpha = .2) +
  annotate("rect", xmin = 9605, xmax = 19834, ymin = 0, ymax = 70,
           fill = "yellow", alpha = .2) +
  annotate("rect", xmin = 19834, xmax = 138746, ymin = 0, ymax = 70,
           fill = "magenta", alpha = .2) 

diskplotnf <- ggplot(data=log.data, aes_string(x="TIME", y="DISK")) + 
  geom_line(color = "green") + xlab("Time (seconds)") + ylab("Disk (kTPS)") +
  theme(axis.text.x = element_text(size = 20, color = "black", 
  face = "bold"), axis.text.y = element_text(size = 13.5, 
  color = "black", face = "bold")) + scale_x_continuous(labels = comma)

diskplotnfa <- diskplotnf +
  annotate("rect", xmin = 48, xmax = 9605, ymin = 0, ymax = 1,
            fill = "blue", alpha = .2) +
  annotate("rect", xmin = 9605, xmax = 19834, ymin = 0, ymax = 1,
           fill = "yellow", alpha = .2) +
  annotate("rect", xmin = 19834, xmax = 138746, ymin = 0, ymax = 1,
           fill = "magenta", alpha = .2) 

grid.arrange(cpuplotnfa,ramplotnfa,diskplotnfa)
# Out:
# plot without title

# %%
## EEL POND LOG.OUT TO ANNOTATED GRAPH
# Highlighting is specific to each run, so user will need to 
# change highlighting and text positions for each run

# Load data, name column headers
# Fill in path to file with desired path here

log.data <- read.table("~/git/ep-streaming/output/streaming/2016-05-27-firstcomp/log.out")
colnames(log.data) <- c("TIME", "CPU","RAM","DISK","5","6","7","8")

# Divide RAM column by 1e6 to get from bytes to MB, DISK by 1e2

log.data$RAM <- log.data$RAM/1e6
log.data$DISK <- log.data$DISK/1e2

# Plot each graph (cpu, ram, disk) separately, 
# then use grid.arrange to stack
# sf = streaming, full

cpuplotsf <- ggplot(data=log.data, aes_string(x="TIME", y="CPU")) + 
  geom_line(color = "blue") + xlab("") + ylab("CPU load (100%)") +
  ggtitle("FULL DATA - streaming") + theme(axis.text.x = 
  element_blank(), axis.text.y = element_text(size = 16, color = "black", 
  face = "bold"), plot.title = element_text(face = "bold", size = 13.5))

cpuplotsfa <- cpuplotsf + annotate("text", x = 5000, y = 80, label = "trimming") +
  annotate("rect", xmin = 47, xmax = 11366, ymin = 0, ymax = 100,
            fill = "blue", alpha = .2) +
  annotate("text", x = 10000, y = 60, label = "diginorm") +
  annotate("rect", xmin = 2899, xmax = 13356, ymin = 0, ymax = 100,
           fill = "yellow", alpha = .3) +
  annotate("text", x =  95000, y = 80, label = "assembly") +
  annotate("rect", xmin = 13356, xmax = 132749, ymin = 0, ymax = 100,
           fill = "magenta", alpha = .2) 

ramplotsf <- ggplot(data=log.data, aes_string(x="TIME", y="RAM")) + 
  geom_line(color = "red") + xlab("") + ylab("RAM (GB)") +
  theme(axis.text.x = element_blank(), axis.text.y = element_text(
    size = 13.5, color = "black", face = "bold"))

ramplotsfa <- ramplotsf + 
  annotate("rect", xmin = 47, xmax = 11366, ymin = 0, ymax = 67,
            fill = "blue", alpha = .2) +
  annotate("rect", xmin = 2899, xmax = 13356, ymin = 0, ymax = 67,
           fill = "yellow", alpha = .3) +
  annotate("rect", xmin = 13356, xmax = 132749, ymin = 0, ymax = 67,
           fill = "magenta", alpha = .2) 

diskplotsf <- ggplot(data=log.data, aes_string(x="TIME", y="DISK")) + 
  geom_line(color = "green") + xlab("Time (seconds)") + ylab("Disk (kTPS)") +
  theme(axis.text.x = element_text(size = 20, color = "black", 
  face = "bold"), axis.text.y = element_text(size = 13.5, 
  color = "black", face = "bold")) + scale_x_continuous(labels = comma)

diskplotsfa <- diskplotsf +
  annotate("rect", xmin = 47, xmax = 11366, ymin = 0, ymax = 1,
            fill = "blue", alpha = .2) +
  annotate("rect", xmin = 2899, xmax = 13356, ymin = 0, ymax = 1,
           fill = "yellow", alpha = .3) +
  annotate("rect", xmin = 13356, xmax = 132749, ymin = 0, ymax = 1,
           fill = "magenta", alpha = .2) 

grid.arrange(cpuplotsfa,ramplotsfa,diskplotsfa)
# Out:
# plot without title

# %%
## EEL POND LOG.OUT TO ANNOTATED GRAPH
# Highlighting is specific to each run, so user will need to 
# change highlighting and text positions for each run

# Load data, name column headers
# Fill in path to file with desired path here

log.data <- read.table("~/git/ep-streaming/output/streaming/2016-05-27-firstcomp/log.thru.diginorm.out")
colnames(log.data) <- c("TIME", "CPU","RAM","DISK","5","6","7","8")

# Divide RAM column by 1e6 to get from bytes to MB, DISK by 1e2

log.data$RAM <- log.data$RAM/1e6
log.data$DISK <- log.data$DISK/1e2

# Plot each graph (cpu, ram, disk) separately, 
# then use grid.arrange to stack
# sdg = streaming, through diginorm (is on full dataset)

cpuplotsdg <- ggplot(data=log.data, aes_string(x="TIME", y="CPU")) + 
  geom_line(color = "blue") + xlab("") + ylab("CPU load (100%)") +
  ggtitle("FULL DATA - streaming through Digital Normalization") + theme(axis.text.x = 
  element_blank(), axis.text.y = element_text(size = 16, color = "black", 
  face = "bold"), plot.title = element_text(face = "bold", size = 13.5))

cpuplotsdga <- cpuplotsdg + annotate("text", x = 1300, y = 80, label = "trimming") +
  annotate("rect", xmin = 0, xmax = 11366, ymin = 0, ymax = 100,
            fill = "blue", alpha = .2) +
  annotate("text", x = 12400, y = 80, label = "diginorm") +
  annotate("rect", xmin = 2899, xmax = 13356, ymin = 0, ymax = 100,
           fill = "magenta", alpha = .2)

ramplotsdg <- ggplot(data=log.data, aes_string(x="TIME", y="RAM")) + 
  geom_line(color = "red") + xlab("") + ylab("RAM (GB)") +
  theme(axis.text.x = element_blank(), axis.text.y = element_text(
    size = 13.5, color = "black", face = "bold"))

ramplotsdga <- ramplotsdg +
  annotate("rect", xmin = 0, xmax = 11366, ymin = 0, ymax = 60,
            fill = "blue", alpha = .2) +
  annotate("rect", xmin = 2899, xmax = 13356, ymin = 0, ymax = 60,
           fill = "magenta", alpha = .2)

diskplotsdg <- ggplot(data=log.data, aes_string(x="TIME", y="DISK")) + 
  geom_line(color = "green") + xlab("Time (seconds)") + ylab("Disk (kTPS)") +
  theme(axis.text.x = element_text(size = 20, color = "black", 
  face = "bold"), axis.text.y = element_text(size = 13.5, 
  color = "black", face = "bold")) + scale_x_continuous(labels = comma)

diskplotsdga <- diskplotsdg +
  annotate("rect", xmin = 0, xmax = 11366, ymin = 0, ymax = 1,
            fill = "blue", alpha = .2) +
  annotate("rect", xmin = 2899, xmax = 13356, ymin = 0, ymax = 1,
           fill = "magenta", alpha = .2)

grid.arrange(cpuplotsdga,ramplotsdga,diskplotsdga)
# Out:
# plot without title

# %%
## EEL POND LOG.OUT TO ANNOTATED GRAPH
# Highlighting is specific to each run, so user will need to 
# change highlighting and text positions for each run

# Load data, name column headers
# Fill in path to file with desired path here

log.data <- read.table("~/git/ep-streaming/output/nonstreaming/2016-05-02/log.thru.diginorm.out")
colnames(log.data) <- c("TIME", "CPU","RAM","DISK","5","6","7","8")

# Divide RAM column by 1e6 to get from bytes to MB, DISK by 1e2

log.data$RAM <- log.data$RAM/1e6
log.data$DISK <- log.data$DISK/1e2

# Plot each graph (cpu, ram, disk) separately, 
# then use grid.arrange to stack
# ndg = nonstreaming, through diginorm (is on full dataset)

cpuplotndg <- ggplot(data=log.data, aes_string(x="TIME", y="CPU")) + 
  geom_line(color = "blue") + xlab("") + ylab("CPU load (100%)") +
  ggtitle("FULL DATA - nonstreaming through Digital Normalization") + theme(axis.text.x = 
  element_blank(), axis.text.y = element_text(size = 16, color = "black", 
  face = "bold"), plot.title = element_text(face = "bold", size = 13.5))

cpuplotndga <- cpuplotndg + annotate("text", x = 6000, y = 80, label = "trimming") +
  annotate("rect", xmin = 40, xmax = 9605, ymin = 0, ymax = 100,
            fill = "blue", alpha = .2) +
  annotate("text", x = 15000, y = 80, label = "diginorm") +
  annotate("rect", xmin = 9605, xmax = 19834, ymin = 0, ymax = 100,
           fill = "magenta", alpha = .2)

ramplotndg <- ggplot(data=log.data, aes_string(x="TIME", y="RAM")) + 
  geom_line(color = "red") + xlab("") + ylab("RAM (GB)") +
  theme(axis.text.x = element_blank(), axis.text.y = element_text(
    size = 13.5, color = "black", face = "bold"))

ramplotndga <- ramplotndg +
  annotate("rect", xmin = 40, xmax = 9605, ymin = 0, ymax =70,
            fill = "blue", alpha = .2) +
  annotate("rect", xmin = 9605, xmax = 19834, ymin = 0, ymax = 70,
           fill = "magenta", alpha = .2)

diskplotndg <- ggplot(data=log.data, aes_string(x="TIME", y="DISK")) + 
  geom_line(color = "green") + xlab("Time (seconds)") + ylab("Disk (kTPS)") +
  theme(axis.text.x = element_text(size = 20, color = "black", 
  face = "bold"), axis.text.y = element_text(size = 13.5, 
  color = "black", face = "bold")) + scale_x_continuous(labels = comma)

diskplotndga <- diskplotndg +
  annotate("rect", xmin = 40, xmax = 9605, ymin = 0, ymax = 1,
            fill = "blue", alpha = .2) +
  annotate("rect", xmin = 9605, xmax = 19834, ymin = 0, ymax = 1,
           fill = "magenta", alpha = .2)

grid.arrange(cpuplotndga,ramplotndga,diskplotndga)
# Out:
# plot without title

# %%
log.data.non <- read.table("~/git/ep-streaming/output/nonstreaming/2016-05-02/log.thru.diginorm.out")
colnames(log.data.non) <- c("TIME", "CPU","RAM","DISK","5","6","7","8")

# Divide RAM column by 1e6 to get from bytes to MB, DISK by 1e2

log.data.non$RAM <- log.data.non$RAM/1e6
log.data.non$DISK <- log.data.non$DISK/1e2

# Plot each graph (cpu, ram, disk) separately, 
# then use grid.arrange to stack
# ndg = nonstreaming, through diginorm (is on full dataset)

cpuplotndg <- ggplot(data=log.data.non, aes_string(x="TIME", y="CPU")) + 
  geom_line(color = "blue") + xlab("") + ylab("CPU load (100%)") +
  ggtitle("FULL DATA - nonstreaming through Digital Normalization") + theme(axis.text.y = 
element_text(size = 16, color = "black", 
  face = "bold"), plot.title = element_text(face = "bold", size = 13.5))

cpuplotndga <- cpuplotndg + annotate("text", x = 6000, y = 80, label = "trimming") +
  annotate("rect", xmin = 40, xmax = 9605, ymin = 0, ymax = 100,
            fill = "blue", alpha = .2) +
  annotate("text", x = 15000, y = 80, label = "diginorm") +
  annotate("rect", xmin = 9605, xmax = 19834, ymin = 0, ymax = 100,
           fill = "magenta", alpha = .2)

log.data.stream <- read.table("~/git/ep-streaming/output/streaming/2016-05-27-firstcomp/log.thru.diginorm.out")
colnames(log.data.stream) <- c("TIME", "CPU","RAM","DISK","5","6","7","8")

# Divide RAM column by 1e6 to get from bytes to MB, DISK by 1e2

log.data.stream$RAM <- log.data.stream$RAM/1e6
log.data.stream$DISK <- log.data.stream$DISK/1e2

# Plot each graph (cpu, ram, disk) separately, 
# then use grid.arrange to stack
# sdg = streaming, through diginorm (is on full dataset)

cpuplotsdg <- ggplot(data=log.data.stream, aes_string(x="TIME", y="CPU")) + 
  geom_line(color = "blue") + xlab("") + ylab("CPU load (100%)") +
  ggtitle("FULL DATA - streaming through Digital Normalization") + theme(axis.text.y = 
  element_text(size = 16, color = "black", 
  face = "bold"), plot.title = element_text(face = "bold", size = 13.5))

cpuplotsdga <- cpuplotsdg + annotate("text", x = 1300, y = 80, label = "trimming") +
  annotate("rect", xmin = 0, xmax = 11366, ymin = 0, ymax = 100,
            fill = "blue", alpha = .2) +
  annotate("text", x = 12400, y = 80, label = "diginorm") +
  annotate("rect", xmin = 2899, xmax = 13356, ymin = 0, ymax = 100,
           fill = "magenta", alpha = .2)

grid.arrange(cpuplotndga,cpuplotsdga)
# Out:
# plot without title

# %%
# Load data, name column headers
# Fill in path to file with desired path here

log.data.non <- read.table("~/git/ep-streaming/output/nonstreaming/2016-05-02/log.thru.diginorm.out")
colnames(log.data.non) <- c("TIME", "CPU","RAM","DISK","5","6","7","8")

# Divide RAM column by 1e6 to get from bytes to MB, DISK by 1e2

log.data.non$RAM <- log.data.non$RAM/1e6
log.data.non$DISK <- log.data.non$DISK/1e2

ramplotndg <- ggplot(data=log.data.non, aes_string(x="TIME", y="RAM")) + 
  geom_line(color = "red") + xlab("") + ylab("RAM (GB)") +
  theme(axis.text.y = element_text(
    size = 13.5, color = "black", face = "bold"))

ramplotndga <- ramplotndg +
  annotate("rect", xmin = 40, xmax = 9605, ymin = 0, ymax =70,
            fill = "blue", alpha = .2) +
  annotate("rect", xmin = 9605, xmax = 19834, ymin = 0, ymax = 70,
           fill = "magenta", alpha = .2)

log.data.stream <- read.table("~/git/ep-streaming/output/streaming/2016-05-27-firstcomp/log.thru.diginorm.out")
colnames(log.data.stream) <- c("TIME", "CPU","RAM","DISK","5","6","7","8")

# Divide RAM column by 1e6 to get from bytes to MB, DISK by 1e2

log.data.stream$RAM <- log.data.stream$RAM/1e6
log.data.stream$DISK <- log.data.stream$DISK/1e2

ramplotsdg <- ggplot(data=log.data.stream, aes_string(x="TIME", y="RAM")) + 
  geom_line(color = "red") + xlab("") + ylab("RAM (GB)") +
  theme(axis.text.y = element_text(
    size = 13.5, color = "black", face = "bold"))

ramplotsdga <- ramplotsdg +
  annotate("rect", xmin = 0, xmax = 11366, ymin = 0, ymax = 60,
            fill = "blue", alpha = .2) +
  annotate("rect", xmin = 2899, xmax = 13356, ymin = 0, ymax = 60,
           fill = "magenta", alpha = .2)



ramplotndgat <- ramplotndga + ggtitle("FULL DATA - nonstreaming through Digital Normalization")
ramplotsdgat <- ramplotsdga + ggtitle("FULL DATA - streaming through Digital Normalization")
grid.arrange(ramplotndgat,ramplotsdgat)
# Out:
# plot without title

# %%
diskplotndgat <- diskplotndga + ggtitle("FULL DATA - nonstreaming through Digital Normalization")
diskplotsdgat <- diskplotsdga + ggtitle("FULL DATA - streaming through Digital Normalization")
grid.arrange(diskplotndgat,diskplotsdgat)
# Out:
# plot without title
